# %%
from util import load_kaggle_ner
sentences, tags = load_kaggle_ner()

# %%
from util import save, data_split
data = load_kaggle_ner()
train_s, test_s, train_l, test_l = data_split(data)
save("../preprocessed_data/kaggle-ner/train.csv", sentences=train_s, labels=train_l)
save("../preprocessed_data/kaggle-ner/test.csv", sentences=test_s, labels=test_l)

# %%
from util import load_kaggle_ner
sentences, tags = load_kaggle_ner("../preprocessed_data/kaggle-ner/train.csv")

# %%
from ner_classifier import SpacyNEClassifier
classifier = SpacyNEClassifier(train_data=sentences)

classifier.train(train_data=sentences, tags=tags, n_iter=1)
# Out:
#   0%|          | 0/1 [02:23<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7335/2640737069.py in <module>
#       2 classifier = SpacyNEClassifier(train_data=sentences)
#       3
# ----> 4 classifier.train(train_data=sentences, tags=tags, n_iter=1)
#
# ~/DataspellProjects/text-classification/src/ner_classifier.py in train(self, train_data, tags, n_iter)
#      91                 for batch in minibatch(examples, size=8):
#      92                     loss = {}
# ---> 93                     self.nlp.update(batch, sgd=optimizer, losses=loss)
#      94                     self.losses.append(loss['ner'])
#      95
#
# ~/programfiles/miniconda3/envs/text-classification/lib/python3.9/site-packages/spacy/language.py in update(self, examples, _, drop, sgd, losses, component_cfg, exclude, annotates)
#    1120         for name, proc in self.pipeline:
# ...
