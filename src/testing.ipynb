# %%
from util import load_kaggle_ner

# %%
data = load_kaggle_ner("../preprocessed_data/kaggle-ner/train.csv")
data.sentences = data.sentences[:100]
data.bio_tags = data.bio_tags[:100]

# %%
from ner_classifier import SpacyNEClassifier
from ner_vectorizer import DoubleTfIdfVectorizer
classifier = SpacyNEClassifier(filepath="../pretrained_models/spacy-trained-kaggle-ner")
vectorizer = DoubleTfIdfVectorizer(ner_classifier=classifier, max_df=0.95, min_df=5)

# %%
vectorizer.fit(preprocessed_text=data)
tf_idf = vectorizer.transform(preprocessed_text=data)

# %%
import pandas as pd
df = pd.DataFrame(tf_idf, columns = vectorizer.get_feature_names())
df
# Out:
#      's  Iran  Iran_NE  Minister  Mr.  Mr._NE    States  States_NE       The  \
# 0   0.0   0.0      0.0  1.000000  0.0     0.0  0.000000   0.000000  0.000000
# 1   0.0   0.0      0.0  0.000000  0.0     0.0  0.000000   0.000000  0.500054
# 2   0.0   0.0      0.0  0.000000  0.0     0.0  0.000000   0.000000  0.000000
# 3   0.0   0.0      0.0  0.000000  0.0     0.0  0.000000   0.000000  0.000000
# 4   0.0   0.0      0.0  0.000000  0.0     0.0  0.000000   0.000000  0.000000
# ..  ...   ...      ...       ...  ...     ...       ...        ...       ...
# 95  0.0   0.0      0.0  0.000000  0.0     0.0  0.510179   0.510179  0.000000
# 96  0.0   0.0      0.0  0.000000  0.0     0.0  0.000000   0.000000  0.000000
# 97  0.0   0.0      0.0  0.000000  0.0     0.0  0.000000   0.000000  1.000000
# 98  0.0   0.0      0.0  0.339473  0.0     0.0  0.000000   0.000000  0.000000
# 99  0.0   0.0      0.0  0.000000  0.0     0.0  0.000000   0.000000  0.000000
#
# ...
